# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardo-alc/Ajuste_Polinomial/blob/master/AjustePolinomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures 
import matplotlib.pyplot as plt 
import pandas as pd 
from timeit import default_timer

dataset = pd.read_csv("Salary_Data.csv") 

X = dataset.iloc[:,:-1].values 
y = dataset.iloc[:,1].values 
lin_reg = LinearRegression()

for n in range(16):
  inicio = default_timer()
  poly_reg = PolynomialFeatures(degree=n)
  
  
  X_poly = poly_reg.fit_transform(X)
  poly_reg.fit(X_poly,y)
  lin_reg.fit(X_poly,y)

  plt.scatter(X,y)
  plt.plot(X,lin_reg.predict(poly_reg.fit_transform(X)))
  fin = default_timer() 
  print("Ajuste polinomial grado", n," (",fin-inicio," s)")
  plt.show()
# Out:
# Ajuste polinomial grado 0  ( 0.021390483000232052  s)
# Ajuste polinomial grado 1  ( 0.020165212999927462  s)
# Ajuste polinomial grado 2  ( 0.027626598000097147  s)
# Ajuste polinomial grado 3  ( 0.020712949999960983  s)
# Ajuste polinomial grado 4  ( 0.020965593000255467  s)
# Ajuste polinomial grado 5  ( 0.019847561000005953  s)
# Ajuste polinomial grado 6  ( 0.12484939300020415  s)
# Ajuste polinomial grado 7  ( 0.021552862999669742  s)
# Ajuste polinomial grado 8  ( 0.02405854599965096  s)
# Ajuste polinomial grado 9  ( 0.0284933920002004  s)
# Ajuste polinomial grado 10  ( 0.0493912659999296  s)
# Ajuste polinomial grado 11  ( 0.14170800100009728  s)
# Ajuste polinomial grado 12  ( 0.5111850019998201  s)
# Ajuste polinomial grado 13  ( 1.846923536000304  s)
# Ajuste polinomial grado 14  ( 7.130305913000029  s)
# Ajuste polinomial grado 15  ( 28.058777627999916  s)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf6a74ea-8207-40af-9313-77eac35e8895" name="files[]" multiple disabled />
#      <output id="result-bf6a74ea-8207-40af-9313-77eac35e8895">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Salary_Data.csv to Salary_Data.csv
